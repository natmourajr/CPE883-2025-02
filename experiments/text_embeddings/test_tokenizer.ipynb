# %%
from text_embeddings import embeddings

# %%
ext = embeddings.HFBertExtractor(model_path='/home/felipefg/dsc/experiments/data/bert_nano_twods_v1/checkpoint-59110')
ext.load_model()

# %%
ext = embeddings.HFBertExtractor(model_path='bert-base-uncased', bos_token='[CLS]', eos_token='[SEP]')
ext.load_model()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
toks = ext.tokenizer.encode('I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.')

# %%
toks = toks[:30]

# %%
ext.tokenizer.encode(ext.tokenizer.decode(toks))
# Out:
# [101,
#  101,
#  1045,
#  2001,
#  6603,
#  2065,
#  3087,
#  2041,
#  2045,
#  2071,
#  4372,
#  7138,
#  2368,
#  2033,
#  2006,
#  2023,
#  2482,
#  1045,
#  2387,
#  1996,
#  2060,
#  2154,
#  1012,
#  2009,
#  2001,
#  1037,
#  1016,
#  1011,
#  2341,
#  2998,
#  2482,
#  102]

# %%
ext.mask_token_inference('[BOS] I want to drink some orange [MASK] . [EOS]')
# Out:
# /home/felipefg/dsc/CPE883-2025-02/experiments/text_embeddings/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2752: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# [('drinks ', 11.33625316619873),
#  ('" ', 10.538260459899902),
#  ('beer ', 10.445294380187988),
#  ('wine ', 10.32514762878418),
#  ('meat ', 10.193626403808594)]

# %%
ext.mask_token_inference('[BOS] This sentence: " I want to drink some orange juice " means in one word: " [MASK] " . [EOS]')
# Out:
# [('Yes ', 7.630692481994629),
#  ('God ', 6.969448566436768),
#  ('yes ', 6.8189191818237305),
#  ('Oh ', 6.7266974449157715),
#  ('T ', 6.630870819091797)]

# %%
text = ext.format_text_prompteol('I want to drink some orange juice')
print(text)
# Out:
# [CLS] This text: " i want to drink some orange juice " means in one word : " [MASK] " . [SEP]

# %%
ext.mask_token_inference(text)
# Out:
# /home/felipefg/dsc/CPE883-2025-02/experiments/text_embeddings/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2752: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# [('juice', 7.377280235290527),
#  ('orange', 6.730526924133301),
#  ('drink', 6.111706256866455),
#  ('please', 6.0280303955078125),
#  ('water', 4.935492515563965)]

# %%
enc = ext.tokenizer.encode('I want to drink some orange juice')

# %%
enc
# Out:
# [5153, 12195, 8355, 20397, 8883, 19331, 8979, 8728]

# %%
ext.tokenizer.tokenize('I want to drink some orange juice')
# Out:
# ['I ', 'want ', 'to ', 'drink ', 'some ', 'orange ', 'ju', 'ice ']

# %%
ext.tokenizer.decode(enc)
# Out:
# 'I  want  to  drink  some  orange  ju ice '

# %%
ext.tokenizer.convert_ids_to_tokens(enc)
# Out:
# ['[CLS]', 'i', 'want', 'to', 'drink', 'some', 'orange', 'juice', '[SEP]']

# %%
''.join(ext.tokenizer.convert_ids_to_tokens(enc))
# Out:
# '[CLS]iwanttodrinksomeorangejuice[SEP]'

# %%
ext.tokenizer.decode?
